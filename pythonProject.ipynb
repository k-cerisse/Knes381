# %%
import numpy as np
import pandas as pd
import os 
for dirname, _, filenames in os.walk('kaggle/input'):
    for filename in filenames:
        print(os.path.join(firname,filename))
import matplotlib.pyplot as plt

df = pd.read_csv('/kaggle/input/datasets/drjohnholash/demo-knes381/subject_1321.csv', header=[0], skiprows=[1,2,3])

x1 = df['TIME']
x2 = df['VO2']
y1 = df['VO2']
y2 = df['FECO2']
y3 = df['VCO2']

fig, ax = plt.subplots(3,1, sharex = False, figsize = (8,10))
fig.subplots_adjust(hspace = 0.2)

ax[0].plot(x1, y1, 'o', label = ('$\dot VO_2$'), c ='r')
ax[0].spines[['top', 'right']].set_visible(False)
ax[0].set(ylabel = ('L/min'))
ax[0].set(xlabel = ('Time (min)'))

ax[1].plot(x2, y2, 'o', label = ('$FECO_2$'), c = 'b')
ax[1].spines[["top", 'right', 'bottom']].set_visible(False)
ax[1].tick_params(bottom = False, labelbottom = False)
ax[1].set(ylabel = ('%'))

ax[2].plot(x2, y3, 'o', label = ('$\dot VCO_2$'), c = 'g')
ax[2].spines[['top', 'right']].set_visible(False)
ax[2].set(ylabel = ('L/min'))
ax[2].set(xlabel = ('$\dot VO_2$ L/min'))

for a in ax:
    a.legend()

fig.savefig("Python_Project.png", dpi=300, bbox_inches = "tight")
fig.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# <>:33: SyntaxWarning: invalid escape sequence '\d'
# <>:20: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# <>:33: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_55/238550933.py:20: SyntaxWarning: invalid escape sequence '\d'
#   ax[0].plot(x1, y1, 'o', label = ('$\dot VO_2$'), c ='r')
# /tmp/ipykernel_55/238550933.py:30: SyntaxWarning: invalid escape sequence '\d'
#   ax[2].plot(x2, y3, 'o', label = ('$\dot VCO_2$'), c = 'g')
# /tmp/ipykernel_55/238550933.py:33: SyntaxWarning: invalid escape sequence '\d'
#   ax[2].set(xlabel = ('$\dot VO_2$ L/min'))
